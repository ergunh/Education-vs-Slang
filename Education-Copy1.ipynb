# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
# Import seaborn and apply its plotting styles
import seaborn as sns
sns.set(font_scale=2, style="white")
import math
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", 104)
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
from scipy.stats import mannwhitneyu

# %%
education = pd.read_csv("Education - EducationReport (1) (1).csv")
education.dropna(axis='rows')
education.head()
# Out:
#   Unnamed: 0    ID   County State  Urban  1970  1980  1990  2000  2019
# 0  2015-2019  1001  Autauga    AL    2.0  0.06  0.12  0.15  0.18  0.27
# 1  2015-2019  1003  Baldwin    AL    3.0  0.07  0.12  0.17  0.23  0.32
# 2  2015-2019  1005  Barbour    AL    6.0  0.07  0.09  0.12  0.11  0.12
# 3  2015-2019  1007     Bibb    AL    1.0  0.04  0.05  0.05  0.07  0.10
# 4  2015-2019  1009   Blount    AL    1.0  0.03  0.05  0.07  0.10  0.13

# %%
education.describe()
# Out:
#                  ID        Urban         1970         1980        1990  \
# count   3150.000000  3144.000000  3124.000000  3132.000000  3137.00000
# mean   30357.680000     5.010496     0.073854     0.115172     0.13562
# std    15196.317985     2.708130     0.039748     0.054530     0.06567
# min     1001.000000     1.000000     0.000000     0.020000     0.04000
# 25%    18171.500000     2.000000     0.050000     0.080000     0.09000
# 50%    29174.000000     6.000000     0.060000     0.100000     0.12000
# 75%    45082.500000     7.000000     0.090000     0.130000     0.16000
# max    56045.000000     9.000000     0.390000     0.480000     0.53000
#
#               2000         2019
# count  3140.000000  3141.000000
# mean      0.165685     0.220032
# std       0.077995     0.095490
# min       0.050000     0.000000
# 25%       0.110000     0.150000
# 50%       0.150000     0.200000
# 75%       0.190000     0.260000
# max       0.640000     0.780000

# %%
p = sns.countplot("Urban",data =education)
p.set_xlabel("Urban Index Score")
p.set_title("Urban Index Distribution")
# Out:
# Text(0.5, 1.0, 'Urban Index Distribution')

# %%
part = education['State'].unique().tolist()
corr_dict = {}
for i in part:
    df = education[(education.State == i)]
    #sns.barplot(x="Urban",y="2019",data = df)
    column_1 = df['Urban']
    column_2 = df["2019"]
    correlation = column_1.corr(column_2)
    if(abs(correlation)>.5):
        corr_dict[i] = correlation
corr_dict
# Out:
# {'AZ': -0.644198450561376,
#  'DE': -0.9819805060619659,
#  'FL': -0.693125708919179,
#  'IL': -0.6081781815286073,
#  'IA': -0.5025715436322338,
#  'KY': -0.5247632846113541,
#  'LA': -0.5023898833058986,
#  'MN': -0.5398804218671762,
#  'MO': -0.5126084092310675,
#  'NV': -0.7154305124884399,
#  'NH': -0.6866602359893941,
#  'OH': -0.6155267375487595,
#  'OR': -0.5375637988389662,
#  'PA': -0.6332817560391005,
#  'SC': -0.5221860133909334,
#  'UT': -0.5076112874167206,
#  'VA': -0.50102078748295,
#  'WI': -0.559527667738753}

# %%
listy = corr_dict.keys()
df2 = education[education['State'].isin(listy)]
df2
g = sns.catplot(
    data=df2, kind="bar",
    x="State", y="2019",hue = 'Urban',height=25,ci = None)

plt.ylabel("% College")
plt.title("Singifcant Urban College Correlations")
# Out:
# Text(0.5, 1.0, 'Singifcant Urban College Correlations')

# %%
df = education.sort_values(by=['2019'],ascending=False)
df = df[df['2019']<=.08]
part = df['County'].unique().tolist()
g = sns.catplot(
    data=df, kind="bar",
    x="County", y="2019",height=45,hue = 'Urban', ci = None)
plt.ylabel("% College")
plt.title("Least College Educated")
# Out:
# Text(0.5, 1.0, 'Least College Educated')

# %%
df = education.sort_values(by=['2019'],ascending=False)
df = df[df['2019']>=.58]
part = df['County'].unique().tolist()
g = sns.catplot(
    data=df, kind="bar",
    x="County", y="2019",height=45,hue = 'Urban', ci = None)
plt.ylabel("% College")
plt.title("Most College Educated")
# Out:
# Text(0.5, 1.0, 'Most College Educated')

# %%
df = education.sort_values(by=['2019'],ascending=False)
df = df[df['2019']>=.5]

sns.histplot(x="2019",data = df,bins =5)
plt.title("Most College Educated Distribution")
# Out:
# Text(0.5, 1.0, 'Most College Educated Distribution')

# %%
#sns.histplot(x="2019",data = education,bins =5,color='grey')
df2 = education[education['2019']<=.15]
df = education[education['2019']>=.3]
df3 = education[education['2019']<.3]
df3 = df3[df3['2019']>.15]
med_list = []
e_list = []
n_list = []
year_list = ['1970','1980','1990','2000','2019']
for i in year_list:
    med_list.append(df3[i].median())
for i in year_list:
    e_list.append(df[i].median())
for i in year_list:
    n_list.append(df2[i].median())
med_list
sns.lineplot(x=year_list,y=med_list)
sns.lineplot(x=year_list,y=e_list)
sns.lineplot(x=year_list,y=n_list)
plt.title("College Education Overtime")
# Out:
# Text(0.5, 1.0, 'College Education Overtime')

# %%
df7 = education[education['Urban']==1]
df2 = df7[df7['2019']<=.15]
df = df7[df7['2019']>=.3]
df3 = df7[df7['2019']<.3]
df3 = df7[df7['2019']>.15]
med_list = []
e_list = []
n_list = []
year_list = ['1970','1980','1990','2000','2019']
for i in year_list:
    med_list.append(df3[i].median())
for i in year_list:
    e_list.append(df[i].median())
for i in year_list:
    n_list.append(df2[i].median())
med_list
sns.lineplot(x=year_list,y=med_list)
sns.lineplot(x=year_list,y=e_list)
sns.lineplot(x=year_list,y=n_list)

plt.title("College Education Overtime")
# Out:
# Text(0.5, 1.0, 'College Education Overtime')

# %%
df7 = education[education['Urban']==2]
df2 = df7[df7['2019']<=.15]
df = df7[df7['2019']>=.3]
df3 = df7[df7['2019']<.3]
df3 = df7[df7['2019']>.15]
med_list = []
e_list = []
n_list = []
year_list = ['1970','1980','1990','2000','2019']
for i in year_list:
    med_list.append(df3[i].median())
for i in year_list:
    e_list.append(df[i].median())
for i in year_list:
    n_list.append(df2[i].median())
med_list
sns.lineplot(x=year_list,y=med_list)
sns.lineplot(x=year_list,y=e_list)
sns.lineplot(x=year_list,y=n_list)
plt.title("College Education Overtime")
# Out:
# Text(0.5, 1.0, 'College Education Overtime')

# %%
df7 = education[education['Urban']==9]
df2 = df7[df7['2019']<=.15]
df = df7[df7['2019']>=.3]
df3 = df7[df7['2019']<.3]
df3 = df7[df7['2019']>.15]
med_list = []
e_list = []
n_list = []
year_list = ['1970','1980','1990','2000','2019']
for i in year_list:
    med_list.append(df3[i].median())
for i in year_list:
    e_list.append(df[i].median())
for i in year_list:
    n_list.append(df2[i].median())
med_list
sns.lineplot(x=year_list,y=med_list)
sns.lineplot(x=year_list,y=e_list)
sns.lineplot(x=year_list,y=n_list)
plt.title("College Education Overtime")
# Out:
# Text(0.5, 1.0, 'College Education Overtime')

# %%
p = sns.histplot(x="2019",data =education,bins = 40)
plt.xlabel("% College Educated by County")
p.set_title("College Education Distribution")
# Out:
# Text(0.5, 1.0, 'College Education Distribution')

# %%
p= sns.barplot(x="Urban",y="2019",data = education)
p.set_xlabel("Urban Index Score")
p.set_ylabel("% College")
p.set_title("% College by Urban Index")
# Out:
# Text(0.5, 1.0, '% College by Urban Index')

# %%
sns.histplot(x="1970",data = education,bins =90)
sns.histplot(data=education, x="1980",bins = 90, color="red")
sns.histplot(data=education, x="1990",bins = 90, color="grey")
sns.histplot(data=education, x="2000",bins = 90, color="darkblue")
sns.histplot(data=education, x="2019",bins = 90, color="green")
plt.xlabel("% with College Degree")
plt.ylabel("Count")
plt.title("College Education Trends")
# Out:
# Text(0.5, 1.0, 'College Education Trends')
